# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\Admin\Downloads\white_wine.csv"

# %%
wine=pd.read_csv(path,sep=";")
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %%
wine.shape
# Out:
# (4898, 12)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.2 KB

# %% [markdown]
# BY looking in the data we can say that quality and density are the dependent variable and all rest are inependent variables,

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# # 1-Missing values

# %%
x=wine.isnull()
sns.heatmap(x,vmax=1,vmin=-1,center=0)

# %% [markdown]
# AS we can see in the graph that there are no missing values in the dataset.

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# In this we can see that mean is larger than the median value which shows right skewness in data.And also the max value is very  large than the value in 3rd Quartile which means heavy outliers are present in data.

# %%
wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# # Histogram with kde plot

# %%
for i, col in enumerate(wine.columns):
    print(i,col)
    plt.figure(i)
    sns.distplot(wine[col],kde=True,hist_kws={'edgecolor':'black'},bins=20)
# Out:
# 0 fixed acidity
# 1 volatile acidity
# 2 citric acid
# 3 residual sugar
# 4 chlorides
# 5 free sulfur dioxide
# 6 total sulfur dioxide
# 7 density
# 8 pH
# 9 sulphates
# 10 alcohol
# 11 quality

# %% [markdown]
# # Boxplot for all columns

# %%
for x,col in enumerate(wine.columns):
    plt.figure(x)
    sns.boxplot(wine[col])

# %% [markdown]
# By seeing the above data we can see many variables which have a lot of

# %%
sns.set_style("whitegrid")
sns.countplot(x="quality",data=wine)

# %% [markdown]
# We can see in the above plot that most of the quality of wines given in the dataset are of quality score of 5,6,7.

# %% [markdown]
# # Multivariate analysis

# %%
#corelation matrix
cor=wine.corr()
cor
plt.subplots(figsize=(20,15))
sns.heatmap(cor,annot=True,fmt=".2g",vmin=-1,vmax=1,center=0,cmap="inferno",annot_kws={"size":15})
plt.xticks(size=20)
plt.yticks(size=20)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  <a list of 12 Text yticklabel objects>)

# %% [markdown]
# By looking in the plot we can see that:
# 1-The variables with nearly negligible relation or no relation with quality are-
# pH,free sulphur dioxide and citric acid.
# 2-The variable with negative relationship are-
# fixed acidity,volatile acidity,residual sugar, chlorides,total sulphur dioxide,density
# 3-The variable with positive relationship are-
# sulphates and alcohol

# %% [markdown]
# So by looking at the data we can say that the quality of wine will get better when-

# %% [markdown]
# The amount of negative related variable will be low and the amount of positive realted variable will be high
