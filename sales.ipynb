# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path=r"C:\Users\Admin\Downloads\sales.csv"

# %%
sales=pd.read_csv(path)
sales
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571  Mode femmes d'été sans manches robes col en V ...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %%
sales.duplicated().sum()
sales.drop_duplicates(inplace=True)
raw_sales=sales.copy()
raw_sales
# Out:
#                                                   title  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1     SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2     2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3     Hot Summer Cool T-shirt pour les femmes Mode T...
# 4     Femmes Shorts d'été à lacets taille élastique ...
# ...                                                 ...
# 1568  Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569  10 couleurs femmes shorts d'été lacent ceintur...
# 1570  Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571  Mode femmes d'été sans manches robes col en V ...
# 1572  Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                              title_orig  price  retail_price  \
# 0     2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1      Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# ...

# %% [markdown]
# Here we are dropping the duplicate values that are present in the dataset,or if there are no duplicates it will return the same dataset without any change

# %%
sales.isnull().sum()

null = sales.isnull().sum().to_frame(name='nulls').T

dtype = sales.dtypes.to_frame(name='dtypes').T

nunique = sales.nunique().to_frame(name='unique').T

pd.concat([null,dtype,nunique],axis=0)
# Out:
#          title title_orig    price retail_price currency_buyer units_sold  \
# nulls        0          0        0            0              0          0
# dtypes  object     object  float64        int64         object      int64
# unique    1201       1203      127          104              1         15
#
#        uses_ad_boosts   rating rating_count rating_five_count  ...  \
# nulls               0        0            0                43  ...
# dtypes          int64  float64        int64           float64  ...
# unique              2      192          761               605  ...
#
#        merchant_rating_count merchant_rating merchant_id  \
# nulls                      0               0           0
# dtypes                 int64         float64      object
# unique                   917             952         958
#
#        merchant_has_profile_picture merchant_profile_picture product_url  \
# nulls                             0                     1314           0
# ...

# %%
round(sales.describe())
# Out:
#         price  retail_price  units_sold  uses_ad_boosts  rating  rating_count  \
# count  1539.0        1539.0      1539.0          1539.0  1539.0        1539.0
# mean      8.0          23.0      4422.0             0.0     4.0         907.0
# std       4.0          30.0      9438.0             0.0     1.0        2002.0
# min       1.0           1.0         1.0             0.0     1.0           0.0
# 25%       6.0           7.0       100.0             0.0     4.0          26.0
# 50%       8.0          10.0      1000.0             0.0     4.0         161.0
# 75%      11.0          26.0      5000.0             1.0     4.0         873.0
# max      49.0         252.0    100000.0             1.0     5.0       20744.0
#
#        rating_five_count  rating_four_count  rating_three_count  \
# count             1496.0             1496.0              1496.0
# mean               451.0              183.0               137.0
# std                989.0              404.0               314.0
# ...

# %%
def hist_count(column, data, exclude_col):

    if column not in exclude_col:

            f, axes = plt.subplots(1,1,figsize=(15,5))

            sns.countplot(x=column, data=data)

            plt.xticks(rotation = 90)

            plt.suptitle(column, fontsize=20)

            plt.show()

    else:

        his = sns.FacetGrid(data, margin_titles=True, aspect = 4, height=3)

        his.map(plt.hist,column,bins=100)

        plt.show()

    plt.show()

exclude_col = ['title', 'title_orig', 'currency_buyer', 'tags', 'merchant_title', 'merchant_name','merchant_info_subtitle', 'merchant_id', 'merchant_profile_picture', 'product_url','product_picture', 'product_id', 'theme', 'crawl_month' ]

for column in sales.columns:

    hist_count(column,sales,exclude_col)
# Out:
# C:\Users\Admin\anaconda3\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Admin\anaconda3\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Admin\anaconda3\anaconda\lib\site-packages\seaborn\axisgrid.py:861: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()
# C:\Users\Admin\anaconda3\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Admin\anaconda3\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %% [markdown]
# The observations made are:

# %% [markdown]
# We can see clearly that the product with colour red,blue,pink,purple,white and black made good sales.

# %% [markdown]
# Also the product with size xs, s and m made most of the sales.

# %% [markdown]
# The rating affects the sales direcctly the higher the rating the more the product is sold.

# %% [markdown]
# The product from cn are mostly in demand

# %% [markdown]
# The product with the price of 10 to 25 are mostly bought

# %%
boxplot = sales.boxplot(column=['rating'])

plt.show()

# %% [markdown]
# The mean rating is almost 4 for all products.
# By looking at the plot above we find that the rating data is negative skewed.

# %%
#corelation matrix
plt.subplots(figsize=(20,15))
sns.heatmap(sales.corr(),annot=True,cmap="viridis",vmax=1,vmin=-1,center=0)

# %% [markdown]
# We can see that in the plot that the ratings directly affect the sale of product. Lower the rating,lower the sale.

# %% [markdown]
# Also the number of ratings also affeccts the sale the higher the number the higher the sale.

# %% [markdown]
# The shipping price directly affect the price of product
